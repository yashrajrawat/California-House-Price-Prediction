# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.rcParams['figure.figsize'] = 11, 5
plt.rcParams['figure.dpi'] = 100

# %%
data=pd.read_csv('housing.csv')
data=pd.DataFrame(data)

# %%
data.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
data.tail()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income  median_house_value  \
# 20635       845.0       330.0         1.5603             78100.0
# 20636       356.0       114.0         2.5568             77100.0
# 20637      1007.0       433.0         1.7000             92300.0
# 20638       741.0       349.0         1.8672             84700.0
# 20639      1387.0       530.0         2.3886             89400.0
#
#       ocean_proximity
# 20635          INLAND
# 20636          INLAND
# 20637          INLAND
# 20638          INLAND
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
data.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        421.385070   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %%
data.isna().sum()
# Out:
# longitude               0
# latitude                0
# housing_median_age      0
# total_rooms             0
# total_bedrooms        207
# population              0
# households              0
# median_income           0
# median_house_value      0
# ocean_proximity         0
# dtype: int64

# %%
data.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value', 'ocean_proximity'],
#       dtype='object')

# %%
len(data.columns)
# Out:
# 10

# %%
d
# Out:
# <AxesSubplot:xlabel='median_house_value', ylabel='median_income'>

# %%
sns.pairplot(data)

# %%
data.corr()['median_house_value']
# Out:
# longitude            -0.045967
# latitude             -0.144160
# housing_median_age    0.105623
# total_rooms           0.134153
# total_bedrooms        0.049686
# population           -0.024650
# households            0.065843
# median_income         0.688075
# median_house_value    1.000000
# Name: median_house_value, dtype: float64

# %%
data['ocean_proximity'].value_counts()
# Out:
# <1H OCEAN     9136
# INLAND        6551
# NEAR OCEAN    2658
# NEAR BAY      2290
# ISLAND           5
# Name: ocean_proximity, dtype: int64

# %%
data['housing_median_age'].median()
# Out:
# 29.0

# %%
m=data['housing_median_age'].median()
age=data['housing_median_age'].apply(lambda x: 'New' if x<m else 'Old')

# %%
age.head()
# Out:
# 0    Old
# 1    New
# 2    Old
# 3    Old
# 4    Old
# Name: housing_median_age, dtype: object

# %%
sns.scatterplot(data['latitude'],data['longitude'],size=age,hue=data['ocean_proximity'])
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#population
sns.scatterplot(data['longitude'],data['latitude'],s=data['population']/100)
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#ocean Proximity
sns.scatterplot(data['longitude'],data['latitude'],s=data['population']/100,hue=data['ocean_proximity'])
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#median house value
sns.scatterplot(data['longitude'],data['latitude'],s=data['population']/100,hue=data['median_house_value'])
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#rooms per household
data['rooms_per_household']=data['total_rooms']/data['households']
#population per household
data['population_per_household']=data['total_bedrooms']/data['total_rooms']
#bedrooms per room
data['bedroom_per_room']=data['total_bedrooms']/data['total_rooms']

# %%
data.shape
# Out:
# (20640, 13)

# %%
data.drop(['latitude','longitude'],axis=1,inplace=True)

# %%
data.shape
# Out:
# (20640, 11)

# %%
features=data.drop('median_house_value',axis=1)
target=data['median_house_value']

# %%
features.columns
# Out:
# Index(['housing_median_age', 'total_rooms', 'total_bedrooms', 'population',
#        'households', 'median_income', 'ocean_proximity', 'rooms_per_household',
#        'population_per_household', 'bedroom_per_room'],
#       dtype='object')

# %%
list(features.columns[:6])+list(features.columns[7:])
# Out:
# ['housing_median_age',
#  'total_rooms',
#  'total_bedrooms',
#  'population',
#  'households',
#  'median_income',
#  'rooms_per_household',
#  'population_per_household',
#  'bedroom_per_room']

# %%
num_attr=list(features.columns[:6])+list(features.columns[7:])
cat_attr=[features.columns[6]]

# %%
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, StandardScaler

# %%
num_pipe=Pipeline([
    ('simple',SimpleImputer(strategy='median')),
    ('scale',StandardScaler())
])
pipe=ColumnTransformer([
    ('num',num_pipe,num_attr),
    ('cat',OneHotEncoder(),cat_attr)
])

# %%
pipe.fit_transform(features)
# Out:
# array([[ 0.98214266, -0.8048191 , -0.97247648, ...,  0.        ,
#          1.        ,  0.        ],
#        [-0.60701891,  2.0458901 ,  1.35714343, ...,  0.        ,
#          1.        ,  0.        ],
#        [ 1.85618152, -0.53574589, -0.82702426, ...,  0.        ,
#          1.        ,  0.        ],
#        ...,
#        [-0.92485123, -0.17499526, -0.12360781, ...,  0.        ,
#          0.        ,  0.        ],
#        [-0.84539315, -0.35559977, -0.30482697, ...,  0.        ,
#          0.        ,  0.        ],
#        [-1.00430931,  0.06840827,  0.18875678, ...,  0.        ,
#          0.        ,  0.        ]])

# %%
features_trans=pipe.fit_transform(features)

# %%
features_trans.shape
# Out:
# (20640, 14)

# %%
from sklearn.metrics import mean_absolute_error,r2_score
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
x_train, x_test, y_train, y_test=train_test_split(features_trans,target,random_state=5)
model=LinearRegression()
model.fit(x_train,y_train)
pred=model.predict(x_test)
mean_absolute_error(y_test,pred)
# Out:
# 50312.565079114174

# %%
target.max()-target.min()
# Out:
# 485002.0

# %%
r2_score(y_test,pred)
# Out:
# 0.6434388142659866

# %% [markdown]
# ### Data Cleaning

# %%
data.isna().sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\WINDOWS\TEMP/ipykernel_9616/1266705919.py in <module>
# ----> 1 data.isna().sum()
#
# NameError: name 'data' is not defined
